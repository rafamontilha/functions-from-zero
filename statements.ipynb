# %% [markdown]
# <a href="https://colab.research.google.com/github/rafamontilha/functions-from-zero/blob/main/statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learning Statemens
# ```

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Variables

# %%
variable=1
